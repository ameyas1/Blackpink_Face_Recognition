# %% [markdown]
# <a href="https://colab.research.google.com/github/ameyas1/Blackpink_Face_Recognition/blob/master/ssd_blackpink_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
zip_ref = zipfile.ZipFile('drive/My Drive/tensorflow-face-detection-master.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import os
import time
import numpy as np
import tensorflow as tf

# BASE_DIR = os.path.dirname(__file__) + '/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = 'tensorflow-face-detection-master/model/frozen_inference_graph_face.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = 'tensorflow-face-detection-master/protos/face_label_map.pbtxt'


class FaceDetector:
    def __init__(self):
        # Load models
        self.detection_graph = tf.Graph()
        self.sess = tf.Session(graph=self.detection_graph)
        with self.detection_graph.as_default():
            od_graph_def = tf.GraphDef()
            with tf.gfile.GFile( PATH_TO_CKPT, 'rb') as fid:
                serialized_graph = fid.read()
                od_graph_def.ParseFromString(serialized_graph)
                tf.import_graph_def(od_graph_def, name='')

        self.image_tensor = self.detection_graph.get_tensor_by_name('image_tensor:0')
        # Each box represents a part of the image where a particular object was detected.
        self.boxes = self.detection_graph.get_tensor_by_name('detection_boxes:0')
        # Each score represent how level of confidence for each of the objects.
        # Score is shown on the result image, together with the class label.
        self.scores = self.detection_graph.get_tensor_by_name('detection_scores:0')
        self.classes = self.detection_graph.get_tensor_by_name('detection_classes:0')
        self.num_detections = self.detection_graph.get_tensor_by_name('num_detections:0')

    def __del__(self):
        self.sess.close()

    def detect(self, image):
        # the array based representation of the image will be used later in order to prepare the
        # result image with boxes and labels on it.
        # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
        image_expanded = np.expand_dims(image, axis=0)

        # Actual detection.
        start_time = time.time()
        (boxes, scores, classes, num_detections) = self.sess.run(
            [self.boxes, self.scores, self.classes, self.num_detections],
            feed_dict={self.image_tensor: image_expanded})
        elapsed_time = time.time() - start_time
        print('inference time cost: {}'.format(elapsed_time))

        # Ratio to real position
        boxes[0, :, [0, 2]] = (boxes[0, :, [0, 2]]*image.shape[0])
        boxes[0, :, [1, 3]] = (boxes[0, :, [1, 3]]*image.shape[1])
        return np.squeeze(boxes).astype(int), np.squeeze(scores)

# %%
# import cv2
# import time
# import numpy as np
# from google.colab.patches import cv2_imshow
# # from detection.FaceDetector import FaceDetector

# face_detector = FaceDetector()
# video_capture = cv2.VideoCapture('blackpink1.jpg')

# print('Start Recognition!')
# prevTime = 0
# while True:
#     ret, frame = video_capture.read()
# #     frame = cv2.resize(frame, (0, 0), fx=1, fy=1)  # resize frame (optional)

#     curTime = time.time()  # calc fps
#     find_results = []

#     frame = frame[:, :, 0:3]
#     boxes, scores = face_detector.detect(frame)
#     face_boxes = boxes[np.argwhere(scores>0.3).reshape(-1)]
#     face_scores = scores[np.argwhere(scores>0.3).reshape(-1)]
#     print('Detected_FaceNum: %d' % len(face_boxes))

#     if len(face_boxes) > 0:
#         for i in range(len(face_boxes)):
#             box = face_boxes[i]
#             cv2.rectangle(frame, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)

#             # plot result idx under box
#             text_x = box[1]
#             text_y = box[2] + 20
#             cv2.putText(frame, 'Score: %2.3f' % face_scores[i], (text_x, text_y), cv2.FONT_HERSHEY_COMPLEX_SMALL,
#                         1, (0, 0, 255), thickness=1, lineType=2)
#     else:
#         print('Unable to align')

#     sec = curTime - prevTime
#     prevTime = curTime
#     fps = 1 / (sec)
#     str = 'FPS: %2.3f' % fps
#     text_fps_x = len(frame[0]) - 150
#     text_fps_y = 20
#     cv2.putText(frame, str, (text_fps_x, text_fps_y),
#                 cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), thickness=1, lineType=2)

#     cv2_imshow(frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# video_capture.release()
# cv2.destroyAllWindows()

# %%
import cv2
import time
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %matplotlib inline

face_detector = FaceDetector()

img = cv2.imread('blackpink1.jpg')
print('Start Recognition!')

boxes, scores = face_detector.detect(img)
face_boxes = boxes[np.argwhere(scores>0.3).reshape(-1)]
face_scores = scores[np.argwhere(scores>0.3).reshape(-1)]
print('Detected_FaceNum: %d' % len(face_boxes))

plt.figure(figsize=(15,15))

if len(face_boxes) > 0:
  for i in range(len(face_boxes)):
    box = face_boxes[i]
    cv2.rectangle(img, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)

            # plot result idx under box
    text_x = box[1]
    text_y = box[2] + 20
    cv2.putText(img, 'Score: %2.3f' % face_scores[i], (text_x, text_y), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        1, (0, 0, 255), thickness=1, lineType=2)
else:
  print('Unable to align')
  
  
cv2_imshow(img)
# Out:
# Start Recognition!
# inference time cost: 2.4358391761779785
# Detected_FaceNum: 4
# <PIL.Image.Image image mode=RGB size=668x393 at 0x7FF35A3ADA20>

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img,img_to_array
import numpy as np
import cv2
import time
import numpy as np
from tensorflow.keras.models import load_model
# from detection.FaceDetector import FaceDetector
# from recognition.FaceRecognition import FaceRecognition
# from classifier.FaceClassifier import FaceClassifier

face_detector = FaceDetector()

fc_model=load_model('drive/My Drive/cp/weights-184-0.94.hdf5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0625 18:52:42.524866 140685794002816 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0625 18:52:42.526749 140685794002816 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0625 18:52:42.529996 140685794002816 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
id_dict={0:'Jennie',1:'Jisoo',2:'Lisa',3:'Rose'}

# %%
img_array = []

# %%
video_capture = cv2.VideoCapture('final_5d1223ad20a0e10014921090_989743.mp4')

print('Start Recognition!')







prevTime = 0
while(video_capture.isOpened()):
    ret, frame = video_capture.read()
    if ret == False:
        break
#     frame = cv2.resize(frame, (0, 0), fx=0.4, fy=0.4)  # resize frame (optional)

    curTime = time.time()  # calc fps
    find_results = []

    frame = frame[:, :, 0:3]
    boxes, scores = face_detector.detect(frame)
    face_boxes = boxes[np.argwhere(scores>0.3).reshape(-1)]
    face_scores = scores[np.argwhere(scores>0.3).reshape(-1)]
    print('Detected_FaceNum: %d' % len(face_boxes))

    if len(face_boxes) > 0:
        for i in range(len(face_boxes)):
            box = face_boxes[i]
            cropped_face = frame[box[0]:box[2], box[1]:box[3], :]
            cropped_face = cv2.resize(cropped_face, (224, 224), interpolation=cv2.INTER_AREA)
            
            x=img_to_array(cropped_face)
            x = preprocess_input(x)
            x=np.expand_dims(x, axis=0)
            classes = fc_model.predict(x, batch_size=32)[0]
            id=np.argmax(classes)
            for j in id_dict:
                if j==id:
                    name=id_dict[id]
            
#             feature = face_recognition.recognize(cropped_face)
#             name = face_classfier.classify(feature)


            cv2.rectangle(frame, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)

            # plot result idx under box
            text_x = box[1]
            text_y = box[2] + 20
            cv2.putText(frame, name, (text_x, text_y), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        1, (0, 0, 255), thickness=1, lineType=2)
    else:
        print('Unable to align')

    sec = curTime - prevTime
    prevTime = curTime
    fps = 1 / (sec)
    str = 'FPS: %2.3f' % fps
    text_fps_x = len(frame[0]) - 150
    text_fps_y = 20
    cv2.putText(frame, str, (text_fps_x, text_fps_y),
                cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), thickness=1, lineType=2)

#     cv2_imshow(frame)
    height, width, layers = frame.shape
    size = (width,height)
    img_array.append(frame)
    
    



video_capture.release()
cv2.destroyAllWindows()

out = cv2.VideoWriter('blackpink.avi',cv2.VideoWriter_fourcc(*'DIVX'), 23, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
# Out:
# Start Recognition!
# inference time cost: 0.8184115886688232
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.0320742130279541
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03216123580932617
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03236055374145508
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03441476821899414
# Detected_FaceNum: 1
# inference time cost: 0.024811506271362305
# Detected_FaceNum: 1
# inference time cost: 0.024138927459716797
# Detected_FaceNum: 1
# inference time cost: 0.02648305892944336
# Detected_FaceNum: 1
# inference time cost: 0.025243520736694336
# Detected_FaceNum: 1
# inference time cost: 0.026259899139404297
# Detected_FaceNum: 1
# inference time cost: 0.025679349899291992
# Detected_FaceNum: 1
# inference time cost: 0.024674654006958008
# Detected_FaceNum: 1
# inference time cost: 0.026278257369995117
# Detected_FaceNum: 1
# inference time cost: 0.026696443557739258
# Detected_FaceNum: 1
# inference time cost: 0.02621316909790039
# Detected_FaceNum: 1
# inference time cost: 0.031002521514892578
# Detected_FaceNum: 1
# inference time cost: 0.024854183197021484
# Detected_FaceNum: 1
# inference time cost: 0.025330066680908203
# Detected_FaceNum: 1
# inference time cost: 0.02584695816040039
# Detected_FaceNum: 1
# inference time cost: 0.025950193405151367
# Detected_FaceNum: 1
# inference time cost: 0.025661468505859375
# Detected_FaceNum: 1
# inference time cost: 0.025099754333496094
# Detected_FaceNum: 1
# inference time cost: 0.0263059139251709
# Detected_FaceNum: 1
# inference time cost: 0.024901390075683594
# Detected_FaceNum: 1
# inference time cost: 0.024232864379882812
# Detected_FaceNum: 1
# inference time cost: 0.025194168090820312
# Detected_FaceNum: 1
# inference time cost: 0.02554154396057129
# Detected_FaceNum: 1
# inference time cost: 0.025576114654541016
# Detected_FaceNum: 1
# inference time cost: 0.025559663772583008
# Detected_FaceNum: 1
# inference time cost: 0.02518630027770996
# Detected_FaceNum: 1
# inference time cost: 0.02535080909729004
# Detected_FaceNum: 1
# inference time cost: 0.02534008026123047
# Detected_FaceNum: 1
# inference time cost: 0.026111841201782227
# Detected_FaceNum: 1
# inference time cost: 0.02533888816833496
# Detected_FaceNum: 1
# inference time cost: 0.026192665100097656
# Detected_FaceNum: 1
# inference time cost: 0.025293827056884766
# Detected_FaceNum: 1
# inference time cost: 0.024631977081298828
# Detected_FaceNum: 1
# inference time cost: 0.0257110595703125
# Detected_FaceNum: 1
# inference time cost: 0.026292800903320312
# Detected_FaceNum: 1
# inference time cost: 0.025600194931030273
# Detected_FaceNum: 1
# inference time cost: 0.025390625
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024808168411254883
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.029180526733398438
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02714705467224121
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02512192726135254
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03701138496398926
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024630069732666016
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02516007423400879
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02588343620300293
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02954244613647461
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03234148025512695
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.026825666427612305
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.027953624725341797
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02445673942565918
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02649092674255371
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025921344757080078
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024776458740234375
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.028481483459472656
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025319576263427734
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024538040161132812
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024930238723754883
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02501845359802246
# Detected_FaceNum: 1
# inference time cost: 0.026645421981811523
# Detected_FaceNum: 1
# inference time cost: 0.02418351173400879
# Detected_FaceNum: 1
# inference time cost: 0.026132583618164062
# Detected_FaceNum: 1
# inference time cost: 0.025442123413085938
# Detected_FaceNum: 1
# inference time cost: 0.02675652503967285
# Detected_FaceNum: 1
# inference time cost: 0.024911165237426758
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025322437286376953
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02830672264099121
# Detected_FaceNum: 1
# inference time cost: 0.025773286819458008
# Detected_FaceNum: 1
# inference time cost: 0.025362491607666016
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02499675750732422
# Detected_FaceNum: 1
# inference time cost: 0.024643898010253906
# Detected_FaceNum: 1
# inference time cost: 0.024973154067993164
# Detected_FaceNum: 1
# inference time cost: 0.02710747718811035
# Detected_FaceNum: 1
# inference time cost: 0.025274276733398438
# Detected_FaceNum: 1
# inference time cost: 0.02458333969116211
# Detected_FaceNum: 1
# inference time cost: 0.025573015213012695
# Detected_FaceNum: 1
# inference time cost: 0.025571823120117188
# Detected_FaceNum: 1
# inference time cost: 0.025298595428466797
# Detected_FaceNum: 1
# inference time cost: 0.02580547332763672
# Detected_FaceNum: 1
# inference time cost: 0.02537369728088379
# Detected_FaceNum: 1
# inference time cost: 0.025075674057006836
# Detected_FaceNum: 1
# inference time cost: 0.025029420852661133
# Detected_FaceNum: 1
# inference time cost: 0.02539658546447754
# Detected_FaceNum: 1
# inference time cost: 0.025730609893798828
# Detected_FaceNum: 1
# inference time cost: 0.024773120880126953
# Detected_FaceNum: 1
# inference time cost: 0.02504277229309082
# Detected_FaceNum: 1
# inference time cost: 0.025622129440307617
# Detected_FaceNum: 1
# inference time cost: 0.0249631404876709
# Detected_FaceNum: 2
# inference time cost: 0.024915218353271484
# Detected_FaceNum: 1
# inference time cost: 0.024792909622192383
# Detected_FaceNum: 1
# inference time cost: 0.025689363479614258
# Detected_FaceNum: 1
# inference time cost: 0.024293899536132812
# Detected_FaceNum: 1
# inference time cost: 0.02484583854675293
# Detected_FaceNum: 1
# inference time cost: 0.02492356300354004
# Detected_FaceNum: 1
# inference time cost: 0.02477741241455078
# Detected_FaceNum: 2
# inference time cost: 0.02520465850830078
# Detected_FaceNum: 1
# inference time cost: 0.024640560150146484
# Detected_FaceNum: 1
# inference time cost: 0.025851011276245117
# Detected_FaceNum: 1
# inference time cost: 0.024257183074951172
# Detected_FaceNum: 2
# inference time cost: 0.026400327682495117
# Detected_FaceNum: 2
# inference time cost: 0.0249483585357666
# Detected_FaceNum: 2
# inference time cost: 0.02502918243408203
# Detected_FaceNum: 2
# inference time cost: 0.02675175666809082
# Detected_FaceNum: 1
# inference time cost: 0.025829076766967773
# Detected_FaceNum: 1
# inference time cost: 0.024420499801635742
# Detected_FaceNum: 1
# inference time cost: 0.024450302124023438
# Detected_FaceNum: 1
# inference time cost: 0.02422642707824707
# Detected_FaceNum: 1
# inference time cost: 0.024744510650634766
# Detected_FaceNum: 1
# inference time cost: 0.024588823318481445
# Detected_FaceNum: 1
# inference time cost: 0.025389432907104492
# Detected_FaceNum: 1
# inference time cost: 0.026023149490356445
# Detected_FaceNum: 1
# inference time cost: 0.02591562271118164
# Detected_FaceNum: 1
# inference time cost: 0.025136709213256836
# Detected_FaceNum: 1
# inference time cost: 0.02542424201965332
# Detected_FaceNum: 1
# inference time cost: 0.025415420532226562
# Detected_FaceNum: 1
# inference time cost: 0.025299072265625
# Detected_FaceNum: 1
# inference time cost: 0.025060176849365234
# Detected_FaceNum: 1
# inference time cost: 0.025933265686035156
# Detected_FaceNum: 1
# inference time cost: 0.025094270706176758
# Detected_FaceNum: 1
# inference time cost: 0.025043487548828125
# Detected_FaceNum: 1
# inference time cost: 0.024875164031982422
# Detected_FaceNum: 1
# inference time cost: 0.028019428253173828
# Detected_FaceNum: 1
# inference time cost: 0.025818586349487305
# Detected_FaceNum: 1
# inference time cost: 0.026152849197387695
# Detected_FaceNum: 1
# inference time cost: 0.025171756744384766
# Detected_FaceNum: 1
# inference time cost: 0.025602102279663086
# Detected_FaceNum: 3
# inference time cost: 0.03988957405090332
# Detected_FaceNum: 1
# inference time cost: 0.02472710609436035
# Detected_FaceNum: 1
# inference time cost: 0.024120330810546875
# Detected_FaceNum: 1
# inference time cost: 0.02592778205871582
# Detected_FaceNum: 2
# inference time cost: 0.02495574951171875
# Detected_FaceNum: 2
# inference time cost: 0.028523683547973633
# Detected_FaceNum: 2
# inference time cost: 0.024784326553344727
# Detected_FaceNum: 2
# inference time cost: 0.027214527130126953
# Detected_FaceNum: 2
# inference time cost: 0.025243520736694336
# Detected_FaceNum: 1
# inference time cost: 0.0244748592376709
# Detected_FaceNum: 2
# inference time cost: 0.02572154998779297
# Detected_FaceNum: 3
# inference time cost: 0.025546550750732422
# Detected_FaceNum: 3
# inference time cost: 0.027817249298095703
# Detected_FaceNum: 4
# inference time cost: 0.02536320686340332
# Detected_FaceNum: 3
# inference time cost: 0.02556920051574707
# Detected_FaceNum: 3
# inference time cost: 0.025561094284057617
# Detected_FaceNum: 3
# inference time cost: 0.025478839874267578
# Detected_FaceNum: 3
# inference time cost: 0.025983095169067383
# Detected_FaceNum: 4
# inference time cost: 0.02502918243408203
# Detected_FaceNum: 4
# inference time cost: 0.025983572006225586
# Detected_FaceNum: 4
# inference time cost: 0.02506852149963379
# Detected_FaceNum: 4
# inference time cost: 0.02581310272216797
# Detected_FaceNum: 4
# inference time cost: 0.024585485458374023
# Detected_FaceNum: 4
# inference time cost: 0.025789737701416016
# Detected_FaceNum: 4
# inference time cost: 0.023570537567138672
# Detected_FaceNum: 4
# inference time cost: 0.024654865264892578
# Detected_FaceNum: 4
# inference time cost: 0.0256655216217041
# Detected_FaceNum: 4
# inference time cost: 0.02519679069519043
# Detected_FaceNum: 5
# inference time cost: 0.02595663070678711
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02556777000427246
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.03149533271789551
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.027820110321044922
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024895906448364258
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02593374252319336
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024956703186035156
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025820493698120117
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.0272371768951416
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025489091873168945
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02573704719543457
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02708601951599121
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025426149368286133
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024727344512939453
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024876117706298828
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024383068084716797
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024740219116210938
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024141311645507812
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02544879913330078
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02857518196105957
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.026032686233520508
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025263309478759766
# Detected_FaceNum: 1
# inference time cost: 0.025473833084106445
# Detected_FaceNum: 4
# inference time cost: 0.02567577362060547
# Detected_FaceNum: 4
# inference time cost: 0.025463104248046875
# Detected_FaceNum: 4
# inference time cost: 0.025310754776000977
# Detected_FaceNum: 4
# inference time cost: 0.025187969207763672
# Detected_FaceNum: 4
# inference time cost: 0.025075435638427734
# Detected_FaceNum: 4
# inference time cost: 0.025646209716796875
# Detected_FaceNum: 4
# inference time cost: 0.025242328643798828
# Detected_FaceNum: 4
# inference time cost: 0.025902509689331055
# Detected_FaceNum: 4
# inference time cost: 0.02768087387084961
# Detected_FaceNum: 4
# inference time cost: 0.025608062744140625
# Detected_FaceNum: 4
# inference time cost: 0.02542734146118164
# Detected_FaceNum: 4
# inference time cost: 0.02828240394592285
# Detected_FaceNum: 4
# inference time cost: 0.025135517120361328
# Detected_FaceNum: 4
# inference time cost: 0.024600505828857422
# Detected_FaceNum: 4
# inference time cost: 0.026721715927124023
# Detected_FaceNum: 4
# inference time cost: 0.02463555335998535
# Detected_FaceNum: 4
# inference time cost: 0.02474212646484375
# Detected_FaceNum: 4
# inference time cost: 0.025097131729125977
# Detected_FaceNum: 4
# inference time cost: 0.024727821350097656
# Detected_FaceNum: 4
# inference time cost: 0.02435755729675293
# Detected_FaceNum: 5
# inference time cost: 0.026249170303344727
# Detected_FaceNum: 5
# inference time cost: 0.026124000549316406
# Detected_FaceNum: 4
# inference time cost: 0.02649068832397461
# Detected_FaceNum: 4
# inference time cost: 0.024872541427612305
# Detected_FaceNum: 4
# inference time cost: 0.028655052185058594
# Detected_FaceNum: 4
# inference time cost: 0.024672985076904297
# Detected_FaceNum: 1
# inference time cost: 0.02519059181213379
# Detected_FaceNum: 1
# inference time cost: 0.02480602264404297
# Detected_FaceNum: 1
# inference time cost: 0.02476978302001953
# Detected_FaceNum: 1
# inference time cost: 0.02501201629638672
# Detected_FaceNum: 1
# inference time cost: 0.027081966400146484
# Detected_FaceNum: 1
# inference time cost: 0.025046110153198242
# Detected_FaceNum: 1
# inference time cost: 0.0253140926361084
# Detected_FaceNum: 1
# inference time cost: 0.02530694007873535
# Detected_FaceNum: 1
# inference time cost: 0.025720596313476562
# Detected_FaceNum: 1
# inference time cost: 0.02514028549194336
# Detected_FaceNum: 1
# inference time cost: 0.024062633514404297
# Detected_FaceNum: 1
# inference time cost: 0.025717496871948242
# Detected_FaceNum: 1
# inference time cost: 0.025946855545043945
# Detected_FaceNum: 1
# inference time cost: 0.024505138397216797
# Detected_FaceNum: 1
# inference time cost: 0.025296688079833984
# Detected_FaceNum: 1
# inference time cost: 0.0297086238861084
# Detected_FaceNum: 1
# inference time cost: 0.024831533432006836
# Detected_FaceNum: 1
# inference time cost: 0.025476932525634766
# Detected_FaceNum: 1
# inference time cost: 0.025727510452270508
# Detected_FaceNum: 1
# inference time cost: 0.026479244232177734
# Detected_FaceNum: 1
# inference time cost: 0.027057647705078125
# Detected_FaceNum: 1
# inference time cost: 0.026032686233520508
# Detected_FaceNum: 1
# inference time cost: 0.025396108627319336
# Detected_FaceNum: 1
# inference time cost: 0.02530193328857422
# Detected_FaceNum: 1
# inference time cost: 0.030776262283325195
# Detected_FaceNum: 1
# inference time cost: 0.024686813354492188
# Detected_FaceNum: 1
# inference time cost: 0.025355815887451172
# Detected_FaceNum: 1
# inference time cost: 0.02405238151550293
# Detected_FaceNum: 1
# inference time cost: 0.0260012149810791
# Detected_FaceNum: 1
# inference time cost: 0.02501964569091797
# Detected_FaceNum: 1
# inference time cost: 0.026116371154785156
# Detected_FaceNum: 1
# inference time cost: 0.02571845054626465
# Detected_FaceNum: 1
# inference time cost: 0.02721261978149414
# Detected_FaceNum: 1
# inference time cost: 0.024837017059326172
# Detected_FaceNum: 3
# inference time cost: 0.026859045028686523
# Detected_FaceNum: 3
# inference time cost: 0.026103734970092773
# Detected_FaceNum: 4
# inference time cost: 0.024789094924926758
# Detected_FaceNum: 4
# inference time cost: 0.025438308715820312
# Detected_FaceNum: 3
# inference time cost: 0.025356769561767578
# Detected_FaceNum: 4
# inference time cost: 0.025750398635864258
# Detected_FaceNum: 3
# inference time cost: 0.02487635612487793
# Detected_FaceNum: 3
# inference time cost: 0.024484634399414062
# Detected_FaceNum: 3
# inference time cost: 0.02542281150817871
# Detected_FaceNum: 3
# inference time cost: 0.02505660057067871
# Detected_FaceNum: 4
# inference time cost: 0.0251767635345459
# Detected_FaceNum: 3
# inference time cost: 0.026104450225830078
# Detected_FaceNum: 3
# inference time cost: 0.024545907974243164
# Detected_FaceNum: 3
# inference time cost: 0.025365829467773438
# Detected_FaceNum: 3
# inference time cost: 0.02592158317565918
# Detected_FaceNum: 3
# inference time cost: 0.025240659713745117
# Detected_FaceNum: 3
# inference time cost: 0.025148391723632812
# Detected_FaceNum: 3
# inference time cost: 0.02490687370300293
# Detected_FaceNum: 3
# inference time cost: 0.02538299560546875
# Detected_FaceNum: 3
# inference time cost: 0.02527141571044922
# Detected_FaceNum: 3
# inference time cost: 0.02571558952331543
# Detected_FaceNum: 3
# inference time cost: 0.024589061737060547
# Detected_FaceNum: 3
# inference time cost: 0.025531530380249023
# Detected_FaceNum: 3
# inference time cost: 0.02511310577392578
# Detected_FaceNum: 3
# inference time cost: 0.02493429183959961
# Detected_FaceNum: 3
# inference time cost: 0.02561354637145996
# Detected_FaceNum: 3
# inference time cost: 0.026073932647705078
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.026056289672851562
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024504423141479492
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024331092834472656
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024822711944580078
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02458643913269043
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024878978729248047
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024110794067382812
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025827407836914062
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02381300926208496
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024232149124145508
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025309085845947266
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024781227111816406
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02385258674621582
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02419257164001465
# Detected_FaceNum: 1
# inference time cost: 0.025218486785888672
# Detected_FaceNum: 1
# inference time cost: 0.025380849838256836
# Detected_FaceNum: 1
# inference time cost: 0.025165081024169922
# Detected_FaceNum: 1
# inference time cost: 0.024879932403564453
# Detected_FaceNum: 1
# inference time cost: 0.025223970413208008
# Detected_FaceNum: 1
# inference time cost: 0.024888038635253906
# Detected_FaceNum: 1
# inference time cost: 0.02460789680480957
# Detected_FaceNum: 1
# inference time cost: 0.02934741973876953
# Detected_FaceNum: 1
# inference time cost: 0.02490687370300293
# Detected_FaceNum: 1
# inference time cost: 0.024719715118408203
# Detected_FaceNum: 1
# inference time cost: 0.024277925491333008
# Detected_FaceNum: 1
# inference time cost: 0.024610280990600586
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024496078491210938
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.027122974395751953
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.028708696365356445
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025120258331298828
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024947166442871094
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024672508239746094
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024772167205810547
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024367332458496094
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024056196212768555
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024866342544555664
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.025444507598876953
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024511098861694336
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.024940013885498047
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.0244448184967041
# Detected_FaceNum: 0
# Unable to align
# inference time cost: 0.02892756462097168
# Detected_FaceNum: 0
# Unable to align
